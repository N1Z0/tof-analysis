# %% [markdown]
# # TOF calibration
#
# Build and save a beamline calibration from gas reference spectra.
#
# **Kernel:** Python (TOF Analysis) · **Setup:** see [README](../README.md)

# %%
# %matplotlib inline

from pathlib import Path
from tof_analysis.interactive_workbench import launch_workbench

bench = launch_workbench(Path("../DATA").resolve())

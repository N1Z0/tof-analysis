# %% [markdown]
# # TOF spectrum analysis
#
# Load a saved calibration and overlay theoretical ion lines.
#
# **Kernel:** Python (TOF Analysis) · **Setup:** [README](../README.md)

# %%
# %matplotlib inline

from pathlib import Path
from tof_analysis.analysis_workbench import launch_analysis

ROOT = Path("..").resolve()
bench = launch_analysis(
    data_dir=ROOT / "DATA",
    calibration_dir=ROOT / "calibration",
    ion_config_path=ROOT / "config" / "custom_ions.json",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       3 from pathlib import Path
#       4 from tof_analysis.analysis_workbench import launch_analysis
#       5
#       6 ROOT = Path("..").resolve()
# ----> 7 bench = launch_analysis(
#       8     data_dir=ROOT / "DATA",
#       9     calibration_dir=ROOT / "calibration",
#      10     ion_config_path=ROOT / "config" / "custom_ions.json",
#
# TypeError: launch_analysis() got an unexpected keyword argument 'settings_path'
